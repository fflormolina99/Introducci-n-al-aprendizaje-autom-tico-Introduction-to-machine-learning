# %% [markdown]
# <center>
# <img src="images/ods_stickers.jpg" />
#
# ## Introducción al Machine Learning
#
# Basado en material de  [Yury Kashnitsky](https://yorko.github.io). Traducido y editado al español por [Ana Georgina Flesia](https://www.linkedin.com/in/georginaflesia/). Este material esta sujeto a los términos y condiciones de la licencia  [Creative Commons CC BY-NC-SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/). Se permite el uso irrestricto para todo propósito no comercial.

# %% [markdown]
# # <center> Ejercicio 1. Análisis exploratorio con Pandas
#
# <img src="images/images/pandas.jpg"  width=50% />

# %% [markdown]
# ** En esta tarea se tiene que usar Pandas para responder preguntas sobre el  dataset [Adult](https://archive.ics.uci.edu/ml/datasets/Adult). **

# %% [markdown]
# Variables y su tipo:
# - `age`: continuous.
# - `workclass`: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.
# - `fnlwgt`: continuous.
# - `education`: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.
# - `education-num`: continuous.
# - `marital-status`: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.
# - `occupation`: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.
# - `relationship`: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.
# - `race`: White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black.
# - `sex`: Female, Male.
# - `capital-gain`: continuous.
# - `capital-loss`: continuous.
# - `hours-per-week`: continuous.
# - `native-country`: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands.
# - `salary`: >50K,<=50K

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max.columns', 100)
# para dibujar gráficos en jupyter notebook
# %matplotlib inline 
import matplotlib.pyplot as plt
import seaborn as sns
# no nos gustan los avisos
# se puden comentar las dos lineas si se quiere tener avisos
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('/home/floormolina99/Aprendizaje Automatico/adult.data.csv')
data.head(10)
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
# 5   37            Private  284582     Masters             14
# 6   49            Private  160187         9th              5
# 7   52   Self-emp-not-inc  209642     HS-grad              9
# 8   31            Private   45781     Masters             14
# 9   42            Private  159449   Bachelors             13
#
#            marital status          occupation    relationship    race  \
# 0           Never-married        Adm-clerical   Not-in-family   White
# 1      Married-civ-spouse     Exec-managerial         Husband   White
# 2                Divorced   Handlers-cleaners   Not-in-family   White
# ...

# %%
print(data.columns)
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'salary'],
#       dtype='object')

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB
# None

# %% [markdown]
# **1. Cuantas mujeres y hombres (variable *sex* ) estan representadas en este dataset?**

# %%
data['sex'].value_counts()
# Out:
#  Male      21790
#  Female    10771
# Name: sex, dtype: int64

# %% [markdown]
# Hay 21790 hombres y 10771 mujeres representados en el dataframe.

# %% [markdown]
# **2. Cual es la edad promedio (variable *age* ) de las mujeres?**

# %%
data[data['sex'] == 'Female']['age'].mean()
#No se por qué me tira NaN, pued el codigo deberia correr bien
# Out:
# nan

# %%
f_filter = data['sex']=='Female'
print("%.2f" % data[f_filter]['age'].mean())
#Pruebo de otra forma equivalente pero sigue tirando error
# Out:
# nan

# %%
data = data.replace(to_replace='Male',value=0,regex=True)
data = data.replace(to_replace='Female',value=1,regex=True)
data.head()
#Reemplazo las respuestas en la variable "sex" para que en vez de ser strings sean numeros enteros, para ver si asi los reconoce
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital status          occupation    relationship    race  sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White    0
# 1   Married-civ-spouse     Exec-managerial         Husband   White    0
# 2             Divorced   Handlers-cleaners   Not-in-family   White    0
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black    0
# 4   Married-civ-spouse      Prof-specialty            Wife   Black    1
#
#    capital-gain  capital-loss  hours-per-week  native-country  salary
# 0          2174             0              40   United-States   <=50K
# ...

# %%
data['sex'].value_counts()
# Out:
# 0    21790
# 1    10771
# Name: sex, dtype: int64

# %%
data[data['sex'] == 1]['age'].mean()
# Out:
# 36.85823043357163

# %%
La edad promedio de las mujeres es 36.86 años

# %% [markdown]
# **3. Cual es el porcentaje de ciudadanos alemanes (variable *native-country*)?**

# %%
data['native-country'].value_counts(normalize=True)
# Out:
#  United-States                 0.895857
#  Mexico                        0.019748
#  ?                             0.017905
#  Philippines                   0.006081
#  Germany                       0.004207
#  Canada                        0.003716
#  Puerto-Rico                   0.003501
#  El-Salvador                   0.003255
#  India                         0.003071
#  Cuba                          0.002918
#  England                       0.002764
#  Jamaica                       0.002488
#  South                         0.002457
#  China                         0.002303
#  Italy                         0.002242
#  Dominican-Republic            0.002150
#  Vietnam                       0.002058
#  Guatemala                     0.001966
#  Japan                         0.001904
#  Poland                        0.001843
#  Columbia                      0.001812
#  Taiwan                        0.001566
#  Haiti                         0.001351
# ...

# %%
data['native-country'].value_counts(normalize=True)['Germany']
# No se por qué me da error porque el comando que estoy usando deberia funcionar
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/anaconda3/lib/python3.8/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.8/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Germany'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# Hay un 0.42% de ciudadanos alemanes

# %% [markdown]
# **4. Cuales son la media y la desviacion estandard de la edad para aquellos que ganan mas de 50k por año (variable *salary*) ?**

# %%
data = data.replace(to_replace='<=50K',value=0,regex=True)
data = data.replace(to_replace='>50K',value=1,regex=True)
data.head(10)
#Cambio de nuevo los nombres de la variable "salary" porque cuando las variables no son números no me corren bien los codigos
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
# 5   37            Private  284582     Masters             14
# 6   49            Private  160187         9th              5
# 7   52   Self-emp-not-inc  209642     HS-grad              9
# 8   31            Private   45781     Masters             14
# 9   42            Private  159449   Bachelors             13
#
#            marital status          occupation    relationship    race  sex  \
# 0           Never-married        Adm-clerical   Not-in-family   White    0
# 1      Married-civ-spouse     Exec-managerial         Husband   White    0
# ...

# %%
data[data['salary'] == 1]['age'].mean()
# Out:
# 44.24984058155847

# %%
data[data['salary'] == 1]['age'].std()
# Out:
# 10.51902771985177

# %% [markdown]
# La media de la edad de los que ganan mas de 50K por año es 44.25 años, y la desviación estandar es 10.52 años.

# %% [markdown]
# **5. Cuales son la media y la desviacion estandard de la edad para aquellos que ganan menos de 50k por año (variable *salary*)?**

# %%
data[data['salary'] == 0]['age'].mean()
# Out:
# 36.78373786407767

# %%
data[data['salary'] == 0]['age'].std()
# Out:
# 14.020088490824813

# %%
La media de la edad de los que ganan mas de 50K por año es 36.78 años, y la desviación estandar es 14.02 años.

# %% [markdown]
# **6. Es cierto que la gente que gana mas que 50K tiene al menos educacion media completa? (variable *education – Bachelors, Prof-school, Assoc-acdm, Assoc-voc, Masters* or *Doctorate*)**

# %%
pd.crosstab(data['education'], data['salary'], normalize=False)
# Out:
# salary            0     1
# education
#  10th           871    62
#  11th          1115    60
#  12th           400    33
#  1st-4th        162     6
#  5th-6th        317    16
#  7th-8th        606    40
#  9th            487    27
#  Assoc-acdm     802   265
#  Assoc-voc     1021   361
#  Bachelors     3134  2221
#  Doctorate      107   306
#  HS-grad       8826  1675
#  Masters        764   959
#  Preschool       51     0
#  Prof-school    153   423
#  Some-college  5904  1387

# %% [markdown]
# Vemos que la afirmación es falsa, si consideramos tener educación media completa como aquellos que cuentan con un "HS-grad", vemos que hay personas con un nivel de educación más bajo que cobran mas de 50K.

# %% [markdown]
# **7. Muestre los estadisticos para cada raza (*race* feature) y cada género (*sex* feature). Use *groupby()* y *describe()*. Encuentre la edad maxima de los hombres de la raza *Amer-Indian-Eskimo*.**

# %%
columns_to_show = ['hours-per-week',
                   'capital-gain',
                   'capital-loss',
                   'age'
                  ]
data.groupby(['race'])[columns_to_show].describe(percentiles=[])
# Out:
#                     hours-per-week                                         \
#                              count       mean        std  min   50%   max
# race
#  Amer-Indian-Eskimo          311.0  40.048232  11.695364  3.0  40.0  84.0
#  Asian-Pac-Islander         1039.0  40.127045  12.556816  1.0  40.0  99.0
#  Black                      3124.0  38.422855  10.315646  1.0  40.0  99.0
#  Other                       271.0  39.468635  11.143755  5.0  40.0  98.0
#  White                     27816.0  40.689100  12.544796  1.0  40.0  99.0
#
#                     capital-gain                                               \
#                            count         mean          std  min  50%      max
# race
#  Amer-Indian-Eskimo        311.0   625.266881  2753.238961  0.0  0.0  27828.0
#  Asian-Pac-Islander       1039.0  1478.358037  9986.156906  0.0  0.0  99999.0
#  Black                    3124.0   609.940461  5139.653447  0.0  0.0  99999.0
# ...

# %%
columns_to_show = ['hours-per-week',
                   'capital-gain',
                   'capital-loss',
                   'age'
                  ]
data.groupby(['sex'])[columns_to_show].describe(percentiles=[])
# Out:
#     hours-per-week                                        capital-gain  \
#              count       mean        std  min   50%   max        count
# sex
# 0          21790.0  42.428086  12.119755  1.0  40.0  99.0      21790.0
# 1          10771.0  36.410361  11.811300  1.0  40.0  99.0      10771.0
#
#                                                  capital-loss              \
#             mean          std  min  50%      max        count        mean
# sex
# 0    1329.370078  8326.312095  0.0  0.0  99999.0      21790.0  100.213309
# 1     568.410547  4924.262944  0.0  0.0  99999.0      10771.0   61.187633
#
#                                        age                                    \
#             std  min  50%     max    count       mean        std   min   50%
# sex
# 0    429.763097  0.0  0.0  3770.0  21790.0  39.433547  13.370630  17.0  38.0
# 1    340.907518  0.0  0.0  4356.0  10771.0  36.858230  14.013697  17.0  35.0
#
#
#       max
# sex
# 0    90.0
# 1    90.0

# %%
columns_to_show = ['hours-per-week',
                   'capital-gain',
                   'capital-loss',
                   'age'
                  ]
data.groupby(['race','sex'])[columns_to_show].describe(percentiles=[])
# Out:
#                         hours-per-week                                         \
#                                  count       mean        std  min   50%   max
# race                sex
#  Amer-Indian-Eskimo 0            192.0  42.197917  11.596280  3.0  40.0  84.0
#                     1            119.0  36.579832  11.046509  4.0  40.0  84.0
#  Asian-Pac-Islander 0            693.0  41.468975  12.387563  1.0  40.0  99.0
#                     1            346.0  37.439306  12.479459  1.0  40.0  99.0
#  Black              0           1569.0  39.997451  10.909413  1.0  40.0  99.0
#                     1           1555.0  36.834084   9.419960  2.0  40.0  99.0
#  Other              0            162.0  41.851852  11.084779  5.0  40.0  98.0
#                     1            109.0  35.926606  10.300761  6.0  40.0  65.0
#  White              0          19174.0  42.668822  12.194633  1.0  40.0  99.0
#                     1           8642.0  36.296691  12.190951  1.0  40.0  99.0
#
# ...

# %%
data[(data['race']=='Amer-Indian-Eskimo') & (data['sex']==0)]['age'].max()
#De nuevo, no se por qué este codigo no corre bien porque debería funcionar
# Out:
# nan

# %% [markdown]
# **8. De las siguientes categorías, cual es la que tiene la mayor proporcion de ricos (>50K): married or single men (variable *marital-status*)? Considere como casados  aquellos que tienen *marital-status* comenzando por *Married* (Married-civ-spouse, Married-spouse-absent or Married-AF-spouse), el resto son bachelors.**

# %%
data.loc[data['marital status'].str.contains("Married")]
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# 5       37            Private  284582      Masters             14
# 6       49            Private  160187          9th              5
# ...    ...                ...     ...          ...            ...
# 32552   43            Private   84661    Assoc-voc             11
# 32554   53            Private  321865      Masters             14
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#                marital status          occupation    relationship    race  \
# 1          Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
data['married-single'] = data['marital status'].apply(lambda x: 'Married' if 'Married' in x else 'Not married')
data.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital status          occupation    relationship    race  sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White    0
# 1   Married-civ-spouse     Exec-managerial         Husband   White    0
# 2             Divorced   Handlers-cleaners   Not-in-family   White    0
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black    0
# 4   Married-civ-spouse      Prof-specialty            Wife   Black    1
#
#    capital-gain  capital-loss  hours-per-week  native-country  salary  \
# 0          2174             0              40   United-States       0
# ...

# %%
data.groupby(['married-single'])['salary'].value_counts(normalize=True)
# Out:
# married-single  salary
# Married         0         0.563080
#                 1         0.436920
# Not married     0         0.935546
#                 1         0.064454
# Name: salary, dtype: float64

# %% [markdown]
# Recordando que salary=0 es un salario menor a 50K y salary=1 es un salario mayor a 50K, vemos que la mayor proporción de ricos se encuentran en el grupo de casados.

# %% [markdown]
# **9. Cual es el máximo de horas que una persona trabaja por semana? (variable *hours-per-week*)? Cuantas personas trabajan ese numero de horas y cual es el porcentaje entre esas personas que ademas ganan mucho (>50K) ?**

# %%
data['hours-per-week'].describe()
# Out:
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000
# Name: hours-per-week, dtype: float64

# %% [markdown]
# El maximo de horas es 99

# %%
data[data['hours-per-week']== 99.].count()
# Out:
# age               85
# workclass         85
# fnlwgt            85
# education         85
# education-num     85
# marital status    85
# occupation        85
# relationship      85
# race              85
# sex               85
# capital-gain      85
# capital-loss      85
# hours-per-week    85
# native-country    85
# salary            85
# married-single    85
# dtype: int64

# %% [markdown]
# Son 85 las personas que trabajan 99 horas a la semana

# %%
data[data['hours-per-week']== 99.]['salary'].value_counts(normalize=True)
# Out:
# 0    0.705882
# 1    0.294118
# Name: salary, dtype: float64

# %% [markdown]
# El 70,6% aproximadamente gana menos de 50K y el 29.4% aproximadamente gana mas de 50K, o sea solo el 29.4% son ricos

# %% [markdown]
# **10. Cuente el numero de horas de trabajo (*hours-per-week*) de aquellos que ganan poco, y de los que ganan mucho (*salary*) para cada pais (*native-country*). Cuales son esos conteos para Japon?**

# %%
data.groupby(['salary','native-country'])['hours-per-week'].describe(percentiles=[])
# Out:
#                           count       mean        std   min   50%   max
# salary native-country
# 0       ?                 437.0  40.164760  12.817002   1.0  40.0  99.0
#         Cambodia           12.0  41.416667   3.088346  40.0  40.0  50.0
#         Canada             82.0  37.914634  13.012056   8.0  40.0  70.0
#         China              55.0  37.381818  11.439844   1.0  40.0  60.0
#         Columbia           57.0  38.684211   8.610952   5.0  40.0  60.0
# ...                         ...        ...        ...   ...   ...   ...
# 1       Thailand            3.0  58.333333  14.433757  50.0  50.0  75.0
#         Trinadad&Tobago     2.0  40.000000   0.000000  40.0  40.0  40.0
#         United-States    7171.0  45.505369  11.025092   1.0  40.0  99.0
#         Vietnam             5.0  39.200000   1.788854  36.0  40.0  40.0
#         Yugoslavia          6.0  49.500000  11.202678  40.0  46.0  65.0
#
# [82 rows x 6 columns]

# %%
data[data['native-country']== 'Japan'].groupby(['salary'])['hours-per-week'].describe(percentiles=[])
#Tampoco se por qué me tira error porque este código deberia correr bien
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [29], in <cell line: 1>()
# ----> 1 data[data['native-country']== 'Japan'].groupby(['salary'])['hours-per-week'].describe(percentiles=[])
#
# File ~/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/generic.py:588, in SeriesGroupBy.describe(self, **kwargs)
#     586 @doc(Series.describe)
#     587 def describe(self, **kwargs):
# --> 588     return super().describe(**kwargs)
#
# File ~/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py:2315, in GroupBy.describe(self, **kwargs)
#    2313 if self.axis == 1:
#    2314     return result.T
# -> 2315 return result.unstack()
#
# File ~/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:4157, in Series.unstack(self, level, fill_value)
#    4114 """
#    4115 Unstack, also known as pivot, Series with MultiIndex to produce DataFrame.
#    4116
# ...
